# %%
pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\home\anaconda3\lib\site-packages (2.27.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\home\anaconda3\lib\site-packages (from requests) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\home\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\home\anaconda3\lib\site-packages (from requests) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\home\anaconda3\lib\site-packages (from requests) (1.26.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bs4
# Out:
# Requirement already satisfied: bs4 in c:\users\home\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\home\anaconda3\lib\site-packages (from bs4) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\home\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup

# %%
def get_topic_imgs(content):
    selection_class = '_1fQZEK' 
    topic_imgs_tags = content.find_all('a', {'class': selection_class})
    topic_imgs = []
    for tag in topic_imgs_tags:
        if tag.img:topic_imgs.append(tag.img["src"])
    return topic_imgs


#mb_images_link

# %%
mb_name=[]
mb_price=[]
mb_configuration_details=[]
mb_images_link=[]

page_num = input('enter no. of pages')
for i in range(1,int(page_num)+1):
    url = "https://www.flipkart.com/mobiles/pr?sid=tyy%2C4io&marketplace=FLIPKART&page=" + str(i)
    req=requests.get(url)
    content=BeautifulSoup(req.content,'html.parser')
    
    name=content.find_all('div',{"class":"_4rR01T"})
    price=content.find_all('div',{"class":"_30jeq3 _1_WHN1"})
    configuration_details = content.find_all('span',{"class":"_2_R_DZ"}) 
    mb_images_link = get_topic_imgs(content)  
    battery = content.find_all('li',{"class":"rgWa7D"})[3].text
    
    
    for i in name:
        mb_name.append(i.text)
    for i in price:
        mb_price.append(i.text)
    for i in configuration_details:
        mb_configuration_details.append(i.text)
# Out:
# enter no. of pages1

# %%
print(len(mb_name))
print(len(mb_price))
print(len(mb_images_link))
print(len(mb_configuration_details))
# Out:
# 24
# 24
# 24
# 24

# %%
import pandas as pd
df=pd.DataFrame({'Product Name':mb_name,'configuration_details':mb_configuration_details,'image_links':mb_images_link,'Price':mb_price})

# %%
df
# Out:
#                                    Product Name  \
# 0          SAMSUNG Galaxy F12 (Sky Blue, 64 GB)
# 1          realme 9 5G (Stargaze White, 128 GB)
# 2         REDMI Note 10S (Deep Sea Blue, 64 GB)
# 3             realme 9 5G (Meteor Black, 64 GB)
# 4           realme 9 5G (Stargaze White, 64 GB)
# 5           REDMI Note 10S (Frost White, 64 GB)
# 6         SAMSUNG Galaxy F12 (Sea Green, 64 GB)
# 7          REDMI Note 10S (Shadow Black, 64 GB)
# 8         REDMI Note 10S (Cosmic Purple, 64 GB)
# 9                  POCO C31 (Royal Blue, 64 GB)
# 10           realme 9 5G (Meteor Black, 128 GB)
# 11       SAMSUNG Galaxy F22 (Denim Blue, 64 GB)
# 12      SAMSUNG Galaxy F22 (Denim Black, 64 GB)
# 13            MOTOROLA e40 (Carbon Gray, 64 GB)
# 14               REDMI 10 (Pacific Blue, 64 GB)
# 15          REDMI 9i Sport (Coral Green, 64 GB)
# 16        REDMI 9i Sport (Metallic Blue, 64 GB)
# 17            realme C35 (Glowing Green, 64 GB)
# 18             REDMI 10 (Midnight Black, 64 GB)
# 19     REDMI Note 10T 5G (Metallic Blue, 64 GB)
# 20                POCO C31 (Shadow Gray, 64 GB)
# 21    Infinix HOT 12 Play (Horizon Blue, 64 GB)
# 22    Infinix HOT 12 Play (Racing Black, 64 GB)
# 23  Infinix HOT 12 Play (Daylight Green, 64 GB)
#
#                 configuration_details  \
# 0   2,76,166 Ratings & 22,290 Reviews
# 1         3,437 Ratings & 284 Reviews
# 2      41,114 Ratings & 2,849 Reviews
# 3        10,044 Ratings & 733 Reviews
# 4        10,044 Ratings & 733 Reviews
# 5      41,114 Ratings & 2,849 Reviews
# 6   2,76,166 Ratings & 22,290 Reviews
# 7      41,114 Ratings & 2,849 Reviews
# 8      41,114 Ratings & 2,849 Reviews
# 9      69,742 Ratings & 4,071 Reviews
# 10        3,437 Ratings & 284 Reviews
# 11     69,904 Ratings & 6,901 Reviews
# 12     69,904 Ratings & 6,901 Reviews
# 13     29,622 Ratings & 3,236 Reviews
# 14     27,815 Ratings & 1,641 Reviews
# 15   1,13,106 Ratings & 6,458 Reviews
# 16   1,13,106 Ratings & 6,458 Reviews
# 17     63,786 Ratings & 4,179 Reviews
# 18     27,815 Ratings & 1,641 Reviews
# 19     19,329 Ratings & 1,089 Reviews
# 20     69,742 Ratings & 4,071 Reviews
# 21        7,275 Ratings & 581 Reviews
# 22        7,275 Ratings & 581 Reviews
# 23        7,275 Ratings & 581 Reviews
#
#                                           image_links    Price
# 0   https://rukminim1.flixcart.com/image/312/312/k...   ₹9,499
# 1   https://rukminim1.flixcart.com/image/312/312/l...  ₹17,499
# 2   https://rukminim1.flixcart.com/image/312/312/k...  ₹12,999
# 3   https://rukminim1.flixcart.com/image/312/312/l...  ₹15,999
# 4   https://rukminim1.flixcart.com/image/312/312/l...  ₹15,999
# 5   https://rukminim1.flixcart.com/image/312/312/k...  ₹12,999
# 6   https://rukminim1.flixcart.com/image/312/312/k...   ₹9,499
# 7   https://rukminim1.flixcart.com/image/312/312/k...  ₹12,999
# 8   https://rukminim1.flixcart.com/image/312/312/k...  ₹12,999
# 9   https://rukminim1.flixcart.com/image/312/312/k...   ₹8,499
# 10  https://rukminim1.flixcart.com/image/312/312/l...  ₹17,499
# 11  https://rukminim1.flixcart.com/image/312/312/k...  ₹10,499
# 12  https://rukminim1.flixcart.com/image/312/312/k...  ₹10,499
# 13  https://rukminim1.flixcart.com/image/312/312/l...   ₹9,999
# 14  https://rukminim1.flixcart.com/image/312/312/l...   ₹9,999
# 15  https://rukminim1.flixcart.com/image/312/312/k...   ₹8,799
# 16  https://rukminim1.flixcart.com/image/312/312/k...   ₹8,799
# 17  https://rukminim1.flixcart.com/image/312/312/l...  ₹11,999
# 18  https://rukminim1.flixcart.com/image/312/312/l...   ₹9,999
# 19  https://rukminim1.flixcart.com/image/312/312/l...  ₹11,999
# 20  https://rukminim1.flixcart.com/image/312/312/k...   ₹8,499
# 21  https://rukminim1.flixcart.com/image/312/312/l...   ₹8,499
# 22  https://rukminim1.flixcart.com/image/312/312/l...   ₹8,499
# 23  https://rukminim1.flixcart.com/image/312/312/l...   ₹8,499

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\home\anaconda3\lib\site-packages (3.0.9)
# Requirement already satisfied: et-xmlfile in c:\users\home\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
df.to_excel(r'C:\Users\home\OneDrive\Documents\py\project.xlsx', sheet_name='Sheet_name_1')
